# %%
# LABORATORIO #1
# Integrantes: Carlos Eduardo Guzmán Torres, Lina Molina, Johan 
# -----------------------------------------------------------------------------------------------------
# 1.1 Suma modular
# Función que calcula la suma de dos enteros módulo p.
# Argumentos: a (primer entero), b (segundo entero), p (módulo entero)
# Return: Resultado de (a + b) mod p
def modular_addition(a: int, b: int, p: int) -> int:
    
    return (a + b) % p # Retorno de la operación

# Pruebas para suma modular
print("=== Pruebas de Suma Modular ===")
print(f"modular_addition(5, 3, 7) = {modular_addition(5, 3, 7)}")
print(f"modular_addition(10, 15, 12) = {modular_addition(10, 15, 12)}")
print(f"modular_addition(-2, 5, 7) = {modular_addition(-2, 5, 7)}")
# Out:
# === Pruebas de Suma Modular ===
# modular_addition(5, 3, 7) = 1
# modular_addition(10, 15, 12) = 1
# modular_addition(-2, 5, 7) = 3

# %%
### 1.2 Resta Modular
# Función que calcula la resta de dos enteros módulo p.
# Argumentos: a (primer entero), b (segundo entero), p (módulo entero)
# Return: Resultado de (a - b) mod p
def modular_subtraction(a: int, b: int, p: int) -> int:
    
    return (a - b) % p # Retorno de la operación

# Pruebas para resta modular
print("\n=== Pruebas de Resta Modular ===")
print(f"modular_subtraction(5, 3, 7) = {modular_subtraction(5, 3, 7)}")
print(f"modular_subtraction(3, 5, 7) = {modular_subtraction(3, 5, 7)}")
print(f"modular_subtraction(10, 15, 12) = {modular_subtraction(10, 15, 12)}")
# Out:
# === Pruebas de Resta Modular ===
# modular_subtraction(5, 3, 7) = 2
# modular_subtraction(3, 5, 7) = 5
# modular_subtraction(10, 15, 12) = 7

# %%
### 1.3 Multiplicación Modular
# Función que calcula la multiplicación de dos enteros módulo p.
# Argumentos: a (primer entero), b (segundo entero), p (módulo entero)
# Return: Resultado de (a * b) mod p
def modular_multiplication(a: int, b: int, p: int) -> int:
    
    return (a * b) % p # Retorno de la operación

# Pruebas para multiplicación modular
print("\n=== Pruebas de Multiplicación Modular ===")
print(f"modular_multiplication(5, 3, 7) = {modular_multiplication(5, 3, 7)}")
print(f"modular_multiplication(4, 6, 11) = {modular_multiplication(4, 6, 11)}")
print(f"modular_multiplication(12, 8, 15) = {modular_multiplication(12, 8, 15)}")
# Out:
# === Pruebas de Multiplicación Modular ===
# modular_multiplication(5, 3, 7) = 1
# modular_multiplication(4, 6, 11) = 2
# modular_multiplication(12, 8, 15) = 6

# %%
### 1.4 Inverso Modular (usando Algoritmo Extendido de Euclides)
# Algoritmo extendido de Euclides para encontrar gcd(a,b) y coeficientes x,y tal que ax + by = gcd(a,b)
def extended_gcd(a: int, b: int) -> tuple:

    if a == 0:
        return b, 0, 1
    
    gcd, x1, y1 = extended_gcd(b % a, a)
    x = y1 - (b // a) * x1
    y = x1
    
    return gcd, x, y

# %%
# Retorna el inverso modular de a módulo p si existe. En caso de que no, lanza un error.
# Argumentos: a (Entero a encontrar su inverso), p (Módulo entero).
# Retorna el inverso modular de a mod p.
def modular_inverse(a: int, p: int) -> int:

    gcd, x, y = extended_gcd(a % p, p)
    
    if gcd != 1:
        raise ValueError(f"El inverso modular de {a} módulo {p} no existe (no son coprimos)")
    
    return x % p

# %%
# Pruebas para inverso modular
print("\n=== Pruebas de Inverso Modular ===")
try:
    inv = modular_inverse(3, 7)
    print(f"modular_inverse(3, 7) = {inv}")  # Esperado: 5
    print(f"Verificación: (3 * {inv}) mod 7 = {(3 * inv) % 7}")  # Debe ser 1
    
    inv = modular_inverse(2, 5)
    print(f"modular_inverse(2, 5) = {inv}")  # Esperado: 3
    print(f"Verificación: (2 * {inv}) mod 5 = {(2 * inv) % 5}")  # Debe ser 1
    
    # Caso donde no existe inverso
    inv = modular_inverse(4, 8)
    print(f"modular_inverse(4, 8) = {inv}")
except ValueError as e:
    print(f"Error esperado: {e}")
# Out:
# === Pruebas de Inverso Modular ===
# modular_inverse(3, 7) = 5
# Verificación: (3 * 5) mod 7 = 1
# modular_inverse(2, 5) = 3
# Verificación: (2 * 3) mod 5 = 1
# Error esperado: El inverso modular de 4 módulo 8 no existe (no son coprimos)

# %%
## Ejercicio 2: Conversión entre Bases

def convert_base(n: str, from_base: int, to_base: int) -> str:
    """
    Convierte un número n de una base from_base a otra base to_base.
    Las bases pueden variar entre 2 y 36.
    
    Args:
        n (str): Número a convertir (como string)
        from_base (int): Base origen (2-36)
        to_base (int): Base destino (2-36)
    
    Returns:
        str: Número convertido en la base destino
    """
    # Validar rango de bases
    if not (2 <= from_base <= 36) or not (2 <= to_base <= 36):
        raise ValueError("Las bases deben estar entre 2 y 36")
    
    # Caracteres para bases hasta 36
    digits = "0123456789ABCDEFGHIJKLMNOPQRSTUVWXYZ"
    
    # Paso 1: Convertir de la base origen a decimal
    decimal_value = 0
    n = n.upper()  # Convertir a mayúsculas para consistencia
    
    for i, digit in enumerate(reversed(n)):
        if digit in digits:
            digit_value = digits.index(digit)
            if digit_value >= from_base:
                raise ValueError(f"Dígito '{digit}' no válido para base {from_base}")
            decimal_value += digit_value * (from_base ** i)
        else:
            raise ValueError(f"Carácter '{digit}' no válido")
    
    # Paso 2: Convertir de decimal a la base destino
    if decimal_value == 0:
        return "0"
    
    result = ""
    while decimal_value > 0:
        remainder = decimal_value % to_base
        result = digits[remainder] + result
        decimal_value //= to_base
    
    return result

# Pruebas para conversión de bases
print("\n=== Pruebas de Conversión de Bases ===")
print(f"convert_base('101', 2, 10) = {convert_base('101', 2, 10)}")  # Esperado: "5"
print(f"convert_base('FF', 16, 10) = {convert_base('FF', 16, 10)}")  # Esperado: "255"
print(f"convert_base('255', 10, 16) = {convert_base('255', 10, 16)}")  # Esperado: "FF"
print(f"convert_base('1010', 2, 8) = {convert_base('1010', 2, 8)}")  # Esperado: "12"
print(f"convert_base('Z', 36, 10) = {convert_base('Z', 36, 10)}")  # Esperado: "35"
# Out:
# === Pruebas de Conversión de Bases ===
# convert_base('101', 2, 10) = 5
# convert_base('FF', 16, 10) = 255
# convert_base('255', 10, 16) = FF
# convert_base('1010', 2, 8) = 12
# convert_base('Z', 36, 10) = 35

# %%
### 3.1 Cifrado de César
def caesar_cipher(text: str, shift: int) -> str:
    """
    Cifra un texto usando el cifrado de César con un desplazamiento shift módulo 26.
    Solo cifra letras del alfabeto inglés, mantiene mayúsculas/minúsculas y otros caracteres.
    
    Args:
        text (str): Texto a cifrar
        shift (int): Desplazamiento para el cifrado
    
    Returns:
        str: Texto cifrado
    """
    result = ""
    
    for char in text:
        if char.isalpha():
            # Determinar si es mayúscula o minúscula
            is_upper = char.isupper()
            
            # Convertir a minúscula para trabajar uniformemente
            char = char.lower()
            
            # Aplicar el desplazamiento módulo 26
            shifted_pos = (ord(char) - ord('a') + shift) % 26
            shifted_char = chr(shifted_pos + ord('a'))
            
            # Restaurar mayúscula si era necesario
            if is_upper:
                shifted_char = shifted_char.upper()
            
            result += shifted_char
        else:
            # Mantener caracteres no alfabéticos sin cambios
            result += char
    
    return result

# %%
# Pruebas para cifrado de César
print("\n=== Pruebas de Cifrado de César ===")
print(f"caesar_cipher('Hello World!', 3) = '{caesar_cipher('Hello World!', 3)}'")  # Esperado: "Khoor Zruog!"
print(f"caesar_cipher('ABC', 1) = '{caesar_cipher('BEEAKFYDJXUQYHYJIQRYHTYJIQFBQDUYJIIKFUHCQD', 0)}'")  # Esperado: "BCD"
print(f"caesar_cipher('ABC', 1) = '{caesar_cipher('BEEAKFYDJXUQYHYJIQRYHTYJIQFBQDUYJIIKFUHCQD', 1)}'")  # Esperado: "BCD"
print(f"caesar_cipher('ABC', 1) = '{caesar_cipher('BEEAKFYDJXUQYHYJIQRYHTYJIQFBQDUYJIIKFUHCQD', 2)}'")  # Esperado: "BCD"
print(f"caesar_cipher('ABC', 1) = '{caesar_cipher('BEEAKFYDJXUQYHYJIQRYHTYJIQFBQDUYJIIKFUHCQD', 3)}'")  # Esperado: "BCD"
print(f"caesar_cipher('ABC', 1) = '{caesar_cipher('BEEAKFYDJXUQYHYJIQRYHTYJIQFBQDUYJIIKFUHCQD', 4)}'")  # Esperado: "BCD"
print(f"caesar_cipher('ABC', 1) = '{caesar_cipher('BEEAKFYDJXUQYHYJIQRYHTYJIQFBQDUYJIIKFUHCQD', 5)}'")  # Esperado: "BCD"
print(f"caesar_cipher('ABC', 1) = '{caesar_cipher('BEEAKFYDJXUQYHYJIQRYHTYJIQFBQDUYJIIKFUHCQD', 6)}'")  # Esperado: "BCD"
print(f"caesar_cipher('ABC', 1) = '{caesar_cipher('BEEAKFYDJXUQYHYJIQRYHTYJIQFBQDUYJIIKFUHCQD', 7)}'")  # Esperado: "BCD"
print(f"caesar_cipher('ABC', 1) = '{caesar_cipher('BEEAKFYDJXUQYHYJIQRYHTYJIQFBQDUYJIIKFUHCQD', 8)}'")  # Esperado: "BCD"
print(f"caesar_cipher('ABC', 1) = '{caesar_cipher('BEEAKFYDJXUQYHYJIQRYHTYJIQFBQDUYJIIKFUHCQD', 9)}'")  # Esperado: "BCD"
print(f"caesar_cipher('ABC', 1) = '{caesar_cipher('BEEAKFYDJXUQYHYJIQRYHTYJIQFBQDUYJIIKFUHCQD', 10)}'")  # Esperado: "BCD"
print(f"caesar_cipher('ABC', 1) = '{caesar_cipher('BEEAKFYDJXUQYHYJIQRYHTYJIQFBQDUYJIIKFUHCQD', 11)}'")  # Esperado: "BCD"
print(f"caesar_cipher('ABC', 1) = '{caesar_cipher('BEEAKFYDJXUQYHYJIQRYHTYJIQFBQDUYJIIKFUHCQD', 12)}'")  # Esperado: "BCD"
print(f"caesar_cipher('ABC', 1) = '{caesar_cipher('BEEAKFYDJXUQYHYJIQRYHTYJIQFBQDUYJIIKFUHCQD', 13)}'")  # Esperado: "BCD"
print(f"caesar_cipher('ABC', 1) = '{caesar_cipher('BEEAKFYDJXUQYHYJIQRYHTYJIQFBQDUYJIIKFUHCQD', 14)}'")  # Esperado: "BCD"
print(f"caesar_cipher('ABC', 1) = '{caesar_cipher('BEEAKFYDJXUQYHYJIQRYHTYJIQFBQDUYJIIKFUHCQD', 15)}'")  # Esperado: "BCD"
print(f"caesar_cipher('ABC', 1) = '{caesar_cipher('BEEAKFYDJXUQYHYJIQRYHTYJIQFBQDUYJIIKFUHCQD', 16)}'")  # Esperado: "BCD"
print(f"caesar_cipher('ABC', 1) = '{caesar_cipher('BEEAKFYDJXUQYHYJIQRYHTYJIQFBQDUYJIIKFUHCQD', 17)}'")  # Esperado: "BCD"
print(f"caesar_cipher('XYZ', 3) = '{caesar_cipher('BEEAKFYDJXUQYHYJIQRYHTYJIQFBQDUYJIIKFUHCQD', 18)}'")  # Esperado: "ABC"
print(f"caesar_cipher('XYZ', 3) = '{caesar_cipher('BEEAKFYDJXUQYHYJIQRYHTYJIQFBQDUYJIIKFUHCQD', 19)}'")  # Esperado: "ABC"
print(f"caesar_cipher('XYZ', 3) = '{caesar_cipher('BEEAKFYDJXUQYHYJIQRYHTYJIQFBQDUYJIIKFUHCQD', 20)}'")  # Esperado: "ABC"
print(f"caesar_cipher('XYZ', 3) = '{caesar_cipher('BEEAKFYDJXUQYHYJIQRYHTYJIQFBQDUYJIIKFUHCQD', 21)}'")  # Esperado: "ABC"
print(f"caesar_cipher('XYZ', 3) = '{caesar_cipher('BEEAKFYDJXUQYHYJIQRYHTYJIQFBQDUYJIIKFUHCQD', 22)}'")  # Esperado: "ABC"
print(f"caesar_cipher('XYZ', 3) = '{caesar_cipher('BEEAKFYDJXUQYHYJIQRYHTYJIQFBQDUYJIIKFUHCQD', 23)}'")  # Esperado: "ABC"
print(f"caesar_cipher('XYZ', 3) = '{caesar_cipher('BEEAKFYDJXUQYHYJIQRYHTYJIQFBQDUYJIIKFUHCQD', 24)}'")  # Esperado: "ABC"
print(f"caesar_cipher('XYZ', 3) = '{caesar_cipher('BEEAKFYDJXUQYHYJIQRYHTYJIQFBQDUYJIIKFUHCQD', 25)}'")  # Esperado: "ABC"
print(f"caesar_cipher('XYZ', 3) = '{caesar_cipher('BEEAKFYDJXUQYHYJIQRYHTYJIQFBQDUYJIIKFUHCQD', 26)}'")  # Esperado: "ABC"
print(f"caesar_cipher('Cryptography 101', 13) = '{caesar_cipher('Cryptography 101', 13)}'")
# Out:
# === Pruebas de Cifrado de César ===
# caesar_cipher('Hello World!', 3) = 'Khoor Zruog!'
# caesar_cipher('ABC', 1) = 'BEEAKFYDJXUQYHYJIQRYHTYJIQFBQDUYJIIKFUHCQD'
# caesar_cipher('ABC', 1) = 'CFFBLGZEKYVRZIZKJRSZIUZKJRGCREVZKJJLGVIDRE'
# caesar_cipher('ABC', 1) = 'DGGCMHAFLZWSAJALKSTAJVALKSHDSFWALKKMHWJESF'
# caesar_cipher('ABC', 1) = 'EHHDNIBGMAXTBKBMLTUBKWBMLTIETGXBMLLNIXKFTG'
# caesar_cipher('ABC', 1) = 'FIIEOJCHNBYUCLCNMUVCLXCNMUJFUHYCNMMOJYLGUH'
# caesar_cipher('ABC', 1) = 'GJJFPKDIOCZVDMDONVWDMYDONVKGVIZDONNPKZMHVI'
# caesar_cipher('ABC', 1) = 'HKKGQLEJPDAWENEPOWXENZEPOWLHWJAEPOOQLANIWJ'
# caesar_cipher('ABC', 1) = 'ILLHRMFKQEBXFOFQPXYFOAFQPXMIXKBFQPPRMBOJXK'
# caesar_cipher('ABC', 1) = 'JMMISNGLRFCYGPGRQYZGPBGRQYNJYLCGRQQSNCPKYL'
# caesar_cipher('ABC', 1) = 'KNNJTOHMSGDZHQHSRZAHQCHSRZOKZMDHSRRTODQLZM'
# caesar_cipher('ABC', 1) = 'LOOKUPINTHEAIRITSABIRDITSAPLANEITSSUPERMAN'
# caesar_cipher('ABC', 1) = 'MPPLVQJOUIFBJSJUTBCJSEJUTBQMBOFJUTTVQFSNBO'
# ...

# %%
### 3.2 Cifrado Afín
def gcd(a: int, b: int) -> int:
    """Calcula el máximo común divisor usando el algoritmo de Euclides"""
    while b:
        a, b = b, a % b
    return a

# %%
def affine_cipher(text: str, a: int, b: int) -> str:
    """
    Cifra un texto usando el cifrado afín con la función E(x) = (a * x + b) mod 26.
    a debe ser coprimo con 26.
    
    Args:
        text (str): Texto a cifrar
        a (int): Multiplicador (debe ser coprimo con 26)
        b (int): Desplazamiento aditivo
    
    Returns:
        str: Texto cifrado
    
    Raises:
        ValueError: Si a no es coprimo con 26
    """
    # Verificar que a es coprimo con 26
    if gcd(a, 26) != 1:
        raise ValueError(f"El valor a={a} debe ser coprimo con 26 (gcd(a,26) debe ser 1)")
    
    result = ""
    
    for char in text:
        if char.isalpha():
            # Determinar si es mayúscula o minúscula
            is_upper = char.isupper()
            
            # Convertir a minúscula y obtener posición (0-25)
            char_pos = ord(char.lower()) - ord('a')
            
            # Aplicar la función afín: E(x) = (a * x + b) mod 26
            encrypted_pos = (a * char_pos + b) % 26
            encrypted_char = chr(encrypted_pos + ord('a'))
            
            # Restaurar mayúscula si era necesario
            if is_upper:
                encrypted_char = encrypted_char.upper()
            
            result += encrypted_char
        else:
            # Mantener caracteres no alfabéticos sin cambios
            result += char
    
    return result

# %%
# Pruebas para cifrado afín
print("\n=== Pruebas de Cifrado Afín ===")
try:
    print(f"affine_cipher('Hello World!', 5, 8) = '{affine_cipher('Hello World!', 5, 8)}'")
    print(f"affine_cipher('CRYPTOGRAPHY', 3, 7) = '{affine_cipher('CRYPTOGRAPHY', 3, 7)}'")
    print(f"affine_cipher('Test', 9, 2) = '{affine_cipher('Test', 9, 2)}'")
    
    # Caso con a no coprimo con 26
    print(f"affine_cipher('Test', 4, 2) = '{affine_cipher('Test', 4, 2)}'")
except ValueError as e:
    print(f"Error esperado: {e}")

# %%
## Funciones de Descifrado (Bonus)

def caesar_decipher(ciphertext: str, shift: int) -> str:
    """Descifra un texto cifrado con César usando el desplazamiento negativo"""
    return caesar_cipher(ciphertext, -shift)

# %%
def affine_decipher(ciphertext: str, a: int, b: int) -> str:
    """
    Descifra un texto cifrado con cifrado afín.
    Usa la función D(y) = a^(-1) * (y - b) mod 26
    """
    if gcd(a, 26) != 1:
        raise ValueError(f"El valor a={a} debe ser coprimo con 26")
    
    # Encontrar el inverso modular de a
    a_inv = modular_inverse(a, 26)
    
    result = ""
    
    for char in ciphertext:
        if char.isalpha():
            is_upper = char.isupper()
            char_pos = ord(char.lower()) - ord('a')
            
            # Aplicar la función de descifrado: D(y) = a^(-1) * (y - b) mod 26
            decrypted_pos = (a_inv * (char_pos - b)) % 26
            decrypted_char = chr(decrypted_pos + ord('a'))
            
            if is_upper:
                decrypted_char = decrypted_char.upper()
            
            result += decrypted_char
        else:
            result += char
    
    return result

# %%
# Pruebas de descifrado
print("\n=== Pruebas de Descifrado ===")
# Cifrado de César
original = "Hello World!"
encrypted = caesar_cipher(original, 3)
decrypted = caesar_decipher(encrypted, 3)
print(f"César - Original: '{original}', Cifrado: '{encrypted}', Descifrado: '{decrypted}'")

# Cifrado Afín
original = "CRYPTOGRAPHY"
encrypted = affine_cipher(original, 5, 8)
decrypted = affine_decipher(encrypted, 5, 8)
print(f"Afín - Original: '{original}', Cifrado: '{encrypted}', Descifrado: '{decrypted}'")

print("\n=== Laboratorio Completado ===")
print("Todas las funciones han sido implementadas y probadas exitosamente.")
